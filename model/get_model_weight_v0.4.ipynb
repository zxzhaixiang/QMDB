# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import time
import sys
import pickle
import random
import scipy.signal as sp_signal
import pandas as pd
from datetime import datetime
import re

from numpy import dot
from numpy.linalg import norm

import hiddenlayer as hl
# %matplotlib inline

# %%
import torch
from torch import nn
# from torch.utils.data import Dataset, DataLoader, TensorDataset
# from torch.utils.data.sampler import SubsetRandomSampler, WeightedRandomSampler
# from torch.autograd import Variable
# from torchvision import transforms

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device is ", device)
# Out:
# Device is  cpu

# %%
class NCF(nn.Module):
    def __init__(self, config):
        super(NCF, self).__init__()
        self.config = config
        self.user_dim = config['nUsers']
        self.movie_dim = config['nMovies']
        self.genres_dim = config['nGenres']
        
        self.g_latent_dim = config['genre_latent_dim']
        self.u_latent_dim = config['user_latent_dim']
        self.i_latent_dim = config['item_latent_dim']
        
        self.user_embedding = nn.Embedding(self.user_dim, self.u_latent_dim, 
                                           max_norm=1, scale_grad_by_freq = True)
        
        self.movie_embedding = nn.Embedding(self.movie_dim, self.i_latent_dim,
                                           max_norm=1, scale_grad_by_freq = True)

        self.genres_layers = nn.Sequential(
                                nn.Linear(self.genres_dim, self.g_latent_dim)
        )
        
        self.fc_layers_relevance = nn.Sequential(
            nn.Linear(self.g_latent_dim + self.i_latent_dim + 64, 64),
            nn.Tanh(),
            nn.Linear(64, 64),
            nn.Tanh(),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )
        
        self.cos_sim = nn.CosineSimilarity(dim=2, eps=1e-6)
        
    def forward(self, user_id, movie_id, genres, em_query):
        user_em = self.user_embedding(user_id)
        movie_em = self.movie_embedding(movie_id)
        genres_em = self.genres_layers(genres)
        
        final_query_em = user_em + genres_em + em_query
        
        relevance_em = torch.cat((movie_em, genres_em, em_query), dim=2)
        relevance_em = relevance_em.view(-1,self.g_latent_dim + self.i_latent_dim + 64)

        relevance_score = self.fc_layers_relevance(relevance_em)

        return relevance_score.view(-1,1), torch.bmm(final_query_em, movie_em.view(-1,self.i_latent_dim, 1)).view(-1,1)

# %%
config = {'nUsers': 4380, 'nMovies': 3868, 
          'nGenres': 22,
          'user_latent_dim': 64, 'item_latent_dim': 64,
          'genre_latent_dim': 64
         }
print(config)
# Out:
# {'nUsers': 4380, 'nMovies': 3868, 'nGenres': 22, 'user_latent_dim': 64, 'item_latent_dim': 64, 'genre_latent_dim': 64}

# %%
CF = NCF(config).to(device)
CF.load_state_dict(torch.load('./../data/processed_data/cfmodel_v04',map_location=torch.device('cpu')))
CF.eval()
# Out:
# NCF(
#   (user_embedding): Embedding(4380, 64, max_norm=1, scale_grad_by_freq=True)
#   (movie_embedding): Embedding(3868, 64, max_norm=1, scale_grad_by_freq=True)
#   (genres_layers): Sequential(
#     (0): Linear(in_features=22, out_features=64, bias=True)
#   )
#   (fc_layers_relevance): Sequential(
#     (0): Linear(in_features=192, out_features=64, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=64, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
#   (cos_sim): CosineSimilarity()
# )

# %%
movie_embedding = CF.movie_embedding.weight.data.detach().cpu().numpy()
user_embedding = CF.user_embedding.weight.data.detach().cpu().numpy()
ave_User_Em = user_embedding.mean(axis=0)

# %%
genres_weight = CF.genres_layers[0].weight.data.detach().cpu().numpy()
genres_bias = CF.genres_layers[0].bias.data.detach().cpu().numpy()

# %%
fc_relevance = [{},{},{}]
for ilayer in range(3):
    fc_relevance[ilayer]['weight'] = CF.fc_layers_relevance[ilayer*2].weight.data.detach().cpu().numpy()
    fc_relevance[ilayer]['bias'] = CF.fc_layers_relevance[ilayer*2].bias.data.detach().cpu().numpy()
    print(fc_relevance[ilayer]['weight'].shape)
# Out:
# (64, 192)
# (64, 64)
# (1, 64)

# %%
tmp = pd.read_csv('./../data/processed_data/ind2qmdb.csv')
ind2qmdbId = dict(zip(tmp.iloc[:,0],tmp.iloc[:,1]))
qmdbId2ind = dict(zip(tmp.iloc[:,1],tmp.iloc[:,0]))

# %%
with open('./../data/processed_data/keyword_embedding.pkl', 'rb') as f:
    kw_embedding = pickle.load(f)

# %%
kw_set = set(kw_embedding.keys())
kw_default_embedding = np.zeros(64)
n=0
for key in kw_embedding:
    kw_default_embedding += kw_embedding[key]
    n+=1

kw_default_embedding/=n

# %%
genres_list = ['tv', 'movie', 'fantasy', 'documentary', 'comedy', 'drama', 'mystery', 'horror', 'science', 'family', 'crime', 'history', 'action', 'adventure', 'fiction', 'music', 'war', 'animation', 'western', 'thriller', 'foreign', 'romance']
genres_dict = dict(zip(genres_list, range(len(genres_list))))

model_weights = {'genres_weight':genres_weight,
                'genres_bias':genres_bias,
                'genres_list': genres_list,
                'genres_dict': genres_dict,
                'movie_embedding': movie_embedding,
                 'ave_user_embedding': ave_User_Em,
                'fc_relevance': fc_relevance,
                 'kw_embedding': kw_embedding,
                 'kw_default_embedding': kw_default_embedding,
                 'kw_set': kw_set,
                 'ind2qmdbId': ind2qmdbId,
                 'qmdbId2ind': qmdbId2ind
                }

# %%
indmap = {'ind2qmdbId': ind2qmdbId,
            'qmdbId2ind': qmdbId2ind}

# %%
with open('./../data/processed_data/model_weights_v04','wb') as f:
    pickle.dump(model_weights, f)

with open('./../data/processed_data/ave_User_Em_v04','wb') as f:
    pickle.dump(ave_User_Em, f)

with open('./../data/processed_data/movie_embedding_v04','wb') as f:
    pickle.dump(movie_embedding, f)  

with open('./../data/processed_data/indmap','wb') as f:
    pickle.dump(indmap, f)

# %%
def get_query_vector(query, model_weights):
    kws = [kw.lower() for kw in query.split(' ')]
    n = 0
    res = np.zeros(64)
    for kw in kws:
        if kw in model_weights['kw_set']:
            print(kw)
            res+=model_weights['kw_embedding'][kw]
            n+=1
    if n==0:
        return model_weights['kw_default_embedding']
    else:
        return res/n

def get_genre_vector(genres, model_weights):
    v = np.zeros((22,1))
    for g in genres:
        if g in model_weights['genres_dict']:
            v[model_weights['genres_dict'][g]]=1
    
    return model_weights['genres_weight'].dot(v).squeeze(1)+model_weights['genres_bias']

# %%
def predict(model_weights, query, user_embedding, genres):

    query_embedding = get_query_vector(query, model_weights)
    genres_embedding = get_genre_vector(genres_q, model_weights)

    final_query_em = ave_User_Em + genres_embedding + query_embedding

    nM = model_weights['movie_embedding'].shape[0]
    relevance_em = np.concatenate((model_weights['movie_embedding'], genres_embedding.reshape(1,64).repeat(nM,axis=0), query_embedding.reshape(1,64).repeat(nM,axis=0)),axis=1)

    for i, fc in enumerate(model_weights['fc_relevance']):
        relevance_em = relevance_em.dot(fc['weight'].T)+fc['bias']
        if i<len(model_weights['fc_relevance'])-1:
            relevance_em = np.tanh(relevance_em)
        else:
            relevance_em = 1. / (1. + np.exp(-relevance_em))

    relevance_score = relevance_em.squeeze(axis=1)
    print(final_query_em.shape)
    print(model_weights['movie_embedding'].T.shape)
    print(final_query_em.dot(model_weights['movie_embedding'].T).shape)
    
    rating_score = final_query_em.dot(model_weights['movie_embedding'].T)
    
    return relevance_score, rating_score

# %%
query = 'john lasseter'
genres_q = ['family','animation']

# %%
rel, rat = predict(model_weights, query, ave_User_Em, genres_q)
# Out:
# john
# lasseter
# (64,)
# (64, 3868)
# (3868,)

# %%
final_score = rel+rat

# %%
ind_combined = np.argsort(final_score)[::-1][:30]

# %%
pd.DataFrame([rel[ind_combined], rat[ind_combined]])
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.999672  0.905575  0.989556  0.999056  0.923518  0.970899  0.971915
# 1  0.632045  0.717348  0.565383  0.508932  0.577643  0.510057  0.507120
#
#          7         8         9   ...       20        21        22        23  \
# 0  0.948860  0.994480  0.999745  ...  0.90286  0.995492  0.999962  0.987424
# 1  0.527522  0.481013  0.444441  ...  0.40077  0.306326  0.300154  0.303642
#
#          24        25        26        27        28        29
# 0  0.800687  0.907888  0.955933  0.990811  0.967741  0.795983
# 1  0.458357  0.339227  0.284136  0.249104  0.233861  0.387042
#
# [2 rows x 30 columns]

# %%
movie_df.iloc[list(ind_combined)]
# Out:
#       Unnamed: 0                                    title  movieId  qmdbId  \
# 3142        3142                          Winnie the Pooh     8962    3143
# 3039        3039                                  Tangled     8768    3040
# 3478        3478                                    Turbo     9564    3479
# 929          929                        Tigger Movie, The     2633     929
# 2619        2619                             Space Chimps     7972    2620
# 3119        3119                          Kung Fu Panda 2     8930    3120
# 1658        1658                         Rugrats Go Wild!     4986    1659
# 3402        3402  Batman: The Dark Knight Returns, Part 2     9417    3403
# 2027        2027                   Pooh's Heffalump Movie     6749    2028
# 1002        1002                                 Dinosaur     2880    1002
# 2888        2888    Dragon Hunters (Chasseurs de dragons)     8494    2889
# 1464        1464                    Hey Arnold! The Movie     4319    1464
# 3146        3146                          Alpha and Omega     8968    3147
# 1480        1480                         Robin and Marian     4361    1480
# 3462        3462                      Monsters University     9531    3463
# 1303        1303                                 Hardball     3830    1303
# 2971        2971                            Despicable Me     8653    2972
# 1465        1465                                Mr. Deeds     4320    1465
# 160          160                                Pinocchio      525     160
# 3847        3847                    The Angry Birds Movie    10398    3847
# 56            56                             First Knight      138      56
# 2066        2066                               Madagascar     6878    2067
# 2674        2674              Madagascar: Escape 2 Africa     8069    2675
# 2722        2722                                 Coraline     8168    2723
# 1650        1650                             Finding Nemo     4916    1651
# 2175        2175                   Cheaper by the Dozen 2     7104    2176
# 3759        3759                  The Secret Life of Pets    10179    3760
# 1546        1546                Return to the Blue Lagoon     4585    1546
# 815          815    Adventures of Elmo in Grouchland, The     2305     815
# 650          650                       Rugrats Movie, The     1852     650
#
#       tmdbId  year                                    genre_kws  \
# 3142   51162  2011                      ['family', 'animation']
# 3039   38757  2010                      ['family', 'animation']
# 3478   77950  2013                      ['family', 'animation']
# 929    15655  2000                      ['family', 'animation']
# 2619   11802  2008                      ['family', 'animation']
# 3119   49444  2011                      ['family', 'animation']
# 1658   20694  2003                      ['family', 'animation']
# 3402  142061  2013                      ['action', 'animation']
# 2027   13682  2005                      ['family', 'animation']
# 1002   10567  2000                      ['family', 'animation']
# 2888   10800  2008                      ['family', 'animation']
# 1464   17710  2002                      ['family', 'animation']
# 3146   12819  2010                      ['family', 'animation']
# 1480   10786  1976  ['action', 'adventure', 'drama', 'romance']
# 3462   62211  2013                      ['family', 'animation']
# 1303   20857  2001                        ['comedy', 'romance']
# 2971   20352  2010                      ['family', 'animation']
# 1465    2022  2002                        ['comedy', 'romance']
# 160    10895  1940                      ['family', 'animation']
# 3847  153518  2016                      ['family', 'animation']
# 56      6520  1995  ['action', 'adventure', 'drama', 'romance']
# 2066     953  2005                      ['family', 'animation']
# 2674   10527  2008                      ['family', 'animation']
# 2722   14836  2009                      ['family', 'animation']
# 1650      12  2003                      ['family', 'animation']
# 2175    9641  2005                                   ['comedy']
# 3759  328111  2016                      ['family', 'animation']
# 1546   13888  1991            ['adventure', 'drama', 'romance']
# 815    16112  1999                                   ['family']
# 650    14444  1998                      ['family', 'animation']
#
#                                                 kws_all
# 3142  oppl duringcreditsstinger hunger stephen bd vi...
# 3039  runner byron selfishness mother animal chamele...
# 3478  animal car pitjor racing super animals ryan po...
# 929   animation woman tigger animals disney the anim...
# 2619  daniels jeff hines kirk aftercreditsstinger ch...
# 3119  animation woman much yuh jennifer panda black ...
# 1658  rugrats a daily and island jungle kids wildlif...
# 3402  comics frank animation peter oliva super retur...
# 2027  animation jimmy jim kath music sansom cute ani...
# 1002  animation alfre cataclysm prehistoric lemur an...
# 2888  animation world hunters dragons destroy patric...
# 1464  animation hey a smith tucker francesca arnold ...
# 3146  ranger wolf dennis alpha and forbidden omega t...
# 1480  robert vhs lester hood and marian connery rich...
# 3462  animation buscemi dan bd video billy college s...
# 1303  baseball reeves michael robbins jordan brian b...
# 2971  oppl mother russell girl super carell space mc...
# 1465  tree liar hampshire sandler letter york billio...
# 160   100 nose kid fun tale charles don blanc walter...
# 3847  pig animation energetic animal anger gad adver...
# 56    arthur round legend chick arthurian excalibur ...
# 2066  animation baron hippopotamus darnell giraffe s...
# 2674  baron darnell jealousy hippopotamus setting ju...
# 2722  dolls a seuss gothic teri tale surreal 3 d hat...
# 1650  protective anxiety harbor orphaned ellen chara...
# 2175  labor pain cheaper holiday levy the 2 lake sha...
# 3759  renaud animation manhattan bunny york hart ani...
# 1546  lagoon teenager brian pacific pelikan island t...
# 815   gary a street to the clash tv movie patinkin s...
# 650   rugrats birth a daily and spade the kids koval...

# %%
ind_rel = np.argsort(rel)[::-1][:100]
ind = [ind_rel[i] for i in np.argsort(rat[ind_rel])[::-1]]

# %%
print(ave_User_Em[:10])
# Out:
# [-0.01720215  0.00289822 -0.00434898  0.03746572  0.04820991  0.00210612
#   0.00730949  0.01476944 -0.04041719  0.01017506]

# %%
print(ind[:10])
# Out:
# [3039, 2619, 3462, 3146, 2708, 1650, 3803, 2450, 2445, 1821]

# %%
movie_df = pd.read_csv(os.path.join('./../data/processed_data/','keywords_all.csv'))

# 380      380   76996  1996                              ['comedy', 'romance']
# 2942    2943   39053  2010                     ['comedy', 'drama', 'romance']
# 700      700    9849  1999  ['comedy', 'fiction', 'science', 'family', 'dr...
#
#                                                 kws_all
# 3039  runner byron selfishness mother animal chamele...
# 2619  daniels jeff hines kirk aftercreditsstinger ch...
# 3462  animation buscemi dan bd video billy college s...
# 3146  ranger wolf dennis alpha and forbidden omega t...
# 2708  tokoro animation gake mother pitjors doi for p...
# 1650  protective anxiety harbor orphaned ellen chara...
# 3803  sandler man backpacker magic skeleton hilariou...
# 2450  pig a dan kavner toplist07 than credits penis ...
# 2445  joakim peter a arn templars the erlend s fight...
# 1821  roseanne animal farm animals range disney rabb...
# 3305  darnell seting monte circus digital cohen conr...
# 2027  animation jimmy jim kath music sansom cute ani...
# 2888  animation world hunters dragons destroy patric...
# 3142  oppl duringcreditsstinger hunger stephen bd vi...
# 2290  bulls got don t farm jonossa black and peasant...
# 929   animation woman tigger animals disney the anim...
# 2279  animation kenan anthropomorphic buscemi pettle...
# 1742  joe animation bunny business and wretch slapst...
# 1390  animation animated pan jeff harriet owen budd ...
# 2722  dolls a seuss gothic teri tale surreal 3 d hat...
# 159   animation breakthroughs national 100 subgenre ...
# 2345  duringcreditsstinger elijah 11 5 2007 happy fe...
# 1460  animation cute mascots redemption disney heart...
# 3478  animal car pitjor racing super animals ryan po...
# 1118  scenes colourful r wuxia fat long calligraphy ...
# 2249  animation hiding suburb omid animal a skunk r ...
# 3220  elijah feet happy bob ola imax george miller d...
# 2906  animation woman for kells magic beautiful tomm...
# 82    julia quinn round world zwick or man topless c...
# 164   mistaken independent reeves michael gwyneth ma...
# ...                                                 ...
# 2372  lrc a mcgregor gentle emily true noonan potter...
# 1658  rugrats a daily and island jungle kids wildlif...
# 1412  stolen catholic summer project jones chicago j...
# 2066  animation baron hippopotamus darnell giraffe s...
# 1464  animation hey a smith tucker francesca arnold ...
# 1867  animation garfield peter hell meyer death as f...
# 2396  independent grandfather sajbel grandchild o fi...
# 3643  animation father daughter duringcreditsstinger...
# 3357  animation sandler duringcreditsstinger mother ...
# 791   robert 100 would a execution and fulfillment b...
# 897   depressing jim zmuda man a topic andy business...
# 1200  birth woman dennis for spade snl to david t a ...
# 3360  disa animation duringcreditsstinger wolf hood ...
# 1212  duel writer tudyk poetry rufus brian a happy s...
# 1465  tree liar hampshire sandler letter york billio...
# 1480  robert vhs lester hood and marian connery rich...
# 315   100 a stephen ramis character sculpting paquet...
# 892   gangster york stuart rob children s a or and a...
# 3418  carolina a touching or sparks haven eye husban...
# 1740  elijah elf birth york zooey for bd video works...
# 3113  mcadams a and depiction marian philosophical w...
# 2305  independent trust moore man david crudup bart ...
# 962   on leelee piznarski diner school josh here mar...
# 2210  armstrong masquerade samaire bad pine teen lin...
# 174   train chick fraser role shirley reversal brend...
# 699   don t letter a sparks luis paul costner newman...
# 772   julia writer garry marshall york gown feet hap...
# 380   alice garner independent other matthew woman m...
# 2942  oppl communication c jonah a mark cyrus reilly...
# 700   favorite a series daryl fish tv my hurley dona...
#
# [100 rows x 8 columns]
